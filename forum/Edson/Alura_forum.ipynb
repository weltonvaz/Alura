# %%
import pandas as pd
import numpy as np

# %%
UNSW11 = pd.read_csv('UNSW-NB15_1.csv', low_memory=False)

# %%
print(UNSW11)
# Out:
#           59.166.0.0   1390   149.171.126.6     53  udp  CON   0.001055  \
# 0         59.166.0.0  33661   149.171.126.9   1024  udp  CON   0.036133
# 1         59.166.0.6   1464   149.171.126.7     53  udp  CON   0.001119
# 2         59.166.0.5   3593   149.171.126.5     53  udp  CON   0.001209
# 3         59.166.0.3  49664   149.171.126.0     53  udp  CON   0.001169
# 4         59.166.0.0  32119   149.171.126.9    111  udp  CON   0.078339
# 5         59.166.0.6   2142   149.171.126.4     53  udp  CON   0.001134
# 6        10.40.182.3      0     10.40.182.3      0  arp  INT   0.000000
# 7         59.166.0.5  40726   149.171.126.6     53  udp  CON   0.001126
# 8         59.166.0.7  12660   149.171.126.4     53  udp  CON   0.001167
# 9        10.40.170.2      0     10.40.170.2      0  arp  INT   0.000000
# 10       10.40.170.2      0     10.40.170.2      0  arp  INT   0.000000
# 11       10.40.182.3      0     10.40.182.3      0  arp  INT   0.000000
# ...

# %%
pd.isnull(UNSW11)
# Out:
#         59.166.0.0   1390  149.171.126.6     53    udp    CON  0.001055  \
# 0            False  False          False  False  False  False     False
# 1            False  False          False  False  False  False     False
# 2            False  False          False  False  False  False     False
# 3            False  False          False  False  False  False     False
# 4            False  False          False  False  False  False     False
# 5            False  False          False  False  False  False     False
# 6            False  False          False  False  False  False     False
# 7            False  False          False  False  False  False     False
# 8            False  False          False  False  False  False     False
# 9            False  False          False  False  False  False     False
# 10           False  False          False  False  False  False     False
# 11           False  False          False  False  False  False     False
# ...
